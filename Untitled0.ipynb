# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiKruthin-Pandreka/Blog_application_MERN/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {
"Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
"Age": [25, 30, 35, 78, 29, 25],
"Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
"Salary": [50000, 60000, 70000, 62000, 8988, 50000]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Age Department  Salary
# 0    Alice   25         HR   50000
# 1      Bob   30         IT   60000
# 2  Charlie   35    Finance   70000
# 3    David   78         IT   62000
# 4      Eve   29         HR    8988
# 5    Alice   25         HR   50000

# %%
df.head(2)
# Out:
#     Name  Age Department  Salary
# 0  Alice   25         HR   50000
# 1    Bob   30         IT   60000
